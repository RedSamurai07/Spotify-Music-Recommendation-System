# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Spotify_history.csv', encoding='latin-1')
df.head()
# Out:
#    Column 1         Timestamp        date      time        artist_name  \
# 0         0  07-08-2013 02:44  07-08-2013  02:44:00       The Mowgli's
# 1         1  07-08-2013 02:45  07-08-2013  02:45:00      Calvin Harris
# 2         2  07-08-2013 02:50  07-08-2013  02:50:00       Lana Del Rey
# 3         3  07-08-2013 02:52  07-08-2013  02:52:00       Lana Del Rey
# 4         4  07-08-2013 03:17  07-08-2013  03:17:00  Empire Of The Sun
#
#                                       track_name  \
# 0                            Say It, Just Say It
# 1  Drinking from the Bottle (feat. Tinie Tempah)
# 2                                    Born To Die
# 3                               Off To The Races
# 4                                      Half Mast
#
#                            album_name  ms_played    platform  shuffle  ...  \
# 0                Waiting For The Dawn       3185  web player    False  ...
# 1                           18 Months      61865  web player    False  ...
# 2  Born To Die - The Paradise Edition     285386  web player    False  ...
# 3  Born To Die - The Paradise Edition     134022  web player    False  ...
# 4                  Walking On A Dream          0  web player    False  ...
#
#    reason_end hour day_of_week  hour_day  seconds_played popularity  \
# 0    clickrow    2           2     02:44           3.185         52
# 1    clickrow    2           2     02:45          61.865         93
# 2     unknown    2           2     02:50         285.386         15
# 3    clickrow    2           2     02:52         134.022         72
# 4     nextbtn    3           2     03:17           0.000         61
#
#    release_year  popularity_bin  listening_time weekday
# 0          2021           51-75           3.185       1
# 1          2022          76-100          61.865       1
# 2          2022            0-25         285.386       1
# 3          2011           51-75         134.022       1
# 4          2005           51-75           0.000       1
#
# [5 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147866 entries, 0 to 147865
# Data columns (total 22 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Column 1        147866 non-null  int64
#  1   Timestamp       147866 non-null  object
#  2   date            147866 non-null  object
#  3   time            147866 non-null  object
#  4   artist_name     147866 non-null  object
#  5   track_name      147866 non-null  object
#  6   album_name      147866 non-null  object
#  7   ms_played       147866 non-null  int64
#  8   platform        147866 non-null  object
#  9   shuffle         147866 non-null  bool
#  10  skipped         147866 non-null  int64
#  11  reason_start    147866 non-null  object
#  12  reason_end      147866 non-null  object
#  13  hour            147866 non-null  int64
#  14  day_of_week     147866 non-null  int64
#  15  hour_day        147866 non-null  object
#  16  seconds_played  147866 non-null  float64
#  17  popularity      147866 non-null  int64
#  18  release_year    147866 non-null  int64
#  19  popularity_bin  146370 non-null  object
#  20  listening_time  147866 non-null  float64
#  21  weekday         147866 non-null  int64
# dtypes: bool(1), float64(2), int64(8), object(11)
# memory usage: 23.8+ MB

# %%
df.shape
# Out:
# (147866, 22)

# %%
df.drop(columns= 'Column 1', inplace=True)

# %%
df.head(5)
# Out:
#           Timestamp        date      time        artist_name  \
# 0  07-08-2013 02:44  07-08-2013  02:44:00       The Mowgli's
# 1  07-08-2013 02:45  07-08-2013  02:45:00      Calvin Harris
# 2  07-08-2013 02:50  07-08-2013  02:50:00       Lana Del Rey
# 3  07-08-2013 02:52  07-08-2013  02:52:00       Lana Del Rey
# 4  07-08-2013 03:17  07-08-2013  03:17:00  Empire Of The Sun
#
#                                       track_name  \
# 0                            Say It, Just Say It
# 1  Drinking from the Bottle (feat. Tinie Tempah)
# 2                                    Born To Die
# 3                               Off To The Races
# 4                                      Half Mast
#
#                            album_name  ms_played    platform  shuffle  \
# 0                Waiting For The Dawn       3185  web player    False
# 1                           18 Months      61865  web player    False
# 2  Born To Die - The Paradise Edition     285386  web player    False
# 3  Born To Die - The Paradise Edition     134022  web player    False
# 4                  Walking On A Dream          0  web player    False
#
#    skipped  ... reason_end hour  day_of_week  hour_day seconds_played  \
# 0        0  ...   clickrow    2            2     02:44          3.185
# 1        0  ...   clickrow    2            2     02:45         61.865
# 2        0  ...    unknown    2            2     02:50        285.386
# 3        0  ...   clickrow    2            2     02:52        134.022
# 4        0  ...    nextbtn    3            2     03:17          0.000
#
#    popularity  release_year  popularity_bin listening_time  weekday
# 0          52          2021           51-75          3.185        1
# 1          93          2022          76-100         61.865        1
# 2          15          2022            0-25        285.386        1
# 3          72          2011           51-75        134.022        1
# 4          61          2005           51-75          0.000        1
#
# [5 rows x 21 columns]

# %%
meaningful_listens_df = df[df['ms_played'] >= 60000].copy()

song_features = meaningful_listens_df.groupby(['artist_name', 'track_name']).agg(
    avg_ms_played=('ms_played', 'mean'),
    listen_count=('ms_played', 'size')
).reset_index()

track_metadata = df[['artist_name', 'track_name', 'popularity', 'release_year']].drop_duplicates(
    subset=['artist_name', 'track_name'], keep='last')

# %%
model_df = pd.merge(song_features, track_metadata, on=['artist_name', 'track_name'], how='left')
model_df.dropna(inplace=True)
model_df.reset_index(drop=True, inplace=True)
model_df.head()
# Out:
#            artist_name                                         track_name  \
# 0  "Weird Al" Yankovic                                                Bob
# 1               *NSYNC  Bye Bye Bye - From Deadpool and Wolverine Soun...
# 2               *NSYNC                    Merry Christmas, Happy Holidays
# 3                .Sinh                                      Coastal Walks
# 4            070 Shake              Guilty Conscience - Tame Impala Remix
#
#    avg_ms_played  listen_count  popularity  release_year
# 0        65300.0             1          41          2013
# 1       200389.0             1          66          2008
# 2       255306.0             1          41          2016
# 3        82894.0             1          26          2021
# 4       214971.0             2          40          2019

# %%
FEATURE_COLS = ['avg_ms_played', 'popularity', 'release_year', 'listen_count']
X = model_df[FEATURE_COLS]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# ### **Spotify Recommendations by `track_name`**

# %%
from sklearn.metrics.pairwise import cosine_similarity
cosine_sim = cosine_similarity(X_scaled)
indices = pd.Series(model_df.index, index=model_df['track_name']).drop_duplicates()

# %%
def get_recommendations(title, N=10, data = model_df, cosine_sim=cosine_sim, indices=indices):
    if title not in indices.index:
        print(f"❌ Error: Song '{title}' not found in the meaningful listen history.")
        return pd.DataFrame()

    
    idx = indices[title]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    sim_scores = sim_scores[1:N+1]
    song_indices = [i[0] for i in sim_scores]

    recommendations = data.iloc[song_indices].copy()
    recommendations['Similarity_Score'] = [i[1] for i in sim_scores]

    return recommendations[['artist_name', 'track_name', 'Similarity_Score', 'popularity', 'release_year']]

# %%
new_recommendations = get_recommendations('Merry Christmas, Happy Holidays', N=10)
new_recommendations = new_recommendations.sort_values(by='popularity', ascending=False) 
new_recommendations
# Out:
#                    artist_name  \
# 7430           No Te Va Gustar
# 11024         The War On Drugs
# 2186   DJ Kelvin El Sacamostro
# 3613         Gioachino Rossini
# 928                   Bee Gees
# 5582            Kevin Johansen
# 6856            Michael BublÃ©
# 7056                     Morat
# 9208              SofÃ­a Reyes
# 9027                  Sheppard
#
#                                               track_name  Similarity_Score  \
# 7430                                                Chau          0.999908
# 11024                                           Red Eyes          0.999897
# 2186                                        Candy Perreo          0.999934
# 3613   Il barbiere di Siviglia (The Barber of Seville...          1.000000
# 928                                You Should Be Dancing          0.999948
# 5582                                         Modern Love          0.999937
# 6856              Have Yourself a Merry Little Christmas          0.999901
# 7056                                    CuÃ¡nto Me Duele          0.999899
# 9208                                       Mal de Amores          0.999933
# 9027                                    Let Me Down Easy          0.999926
#
#        popularity  release_year
# 7430           58          2023
# 11024          52          2020
# 2186           47          2018
# 3613           46          2018
# 928            43          2017
# 5582           40          2016
# 6856           39          2015
# 7056           39          2015
# 9208           29          2011
# 9027           16          2006

# %% [markdown]
# ### **Spotify Recommendations by `artist_name` & `track_name`**

# %%
model_df['combined_key'] = model_df['artist_name'] + ' - ' + model_df['track_name']
indices = pd.Series(model_df.index, index=model_df['combined_key']).drop_duplicates()

# %%
def get_recommendations_combined(artist, title, N=10, data=model_df, cosine_sim=cosine_sim, indices=indices):
    search_key = artist + ' - ' + title
    if search_key not in indices.index:
        print(f"❌ Error: Song '{title}' by '{artist}' not found in the meaningful listen history.")
        return pd.DataFrame()

    idx = indices[search_key]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:N+1]
    song_indices = [i[0] for i in sim_scores]

    recommendations = data.iloc[song_indices].copy()
    recommendations['Similarity_Score'] = [i[1] for i in sim_scores]

    return recommendations[['artist_name', 'track_name', 'Similarity_Score', 'popularity', 'release_year']]

# %%
recommendations_df = get_recommendations_combined('Lana Del Rey', 'Born To Die', N=5)
recommendations_df = recommendations_df.sort_values(by = 'popularity', ascending = False)
recommendations_df
# Out:
#                                          artist_name  \
# 5394                                      Kanye West
# 6799                             Maverick City Music
# 9353                                           TEEKS
# 8458                                   Ramin Djawadi
# 5763  La Arrolladora Banda El LimÃ³n De Rene Camacho
#
#                                         track_name  Similarity_Score  \
# 5394                        Breathe In Breathe Out          0.999894
# 6799  Kingdom (feat. Naomi Raine & Chandler Moore)          0.999904
# 9353                                Never Be Apart          0.999912
# 8458                                      Khaleesi          0.999903
# 5763                              Llamada De Mi Ex          0.999898
#
#       popularity  release_year
# 5394          79          2011
# 6799          71          2010
# 9353          59          2008
# 8458          52          2007
# 5763          52          2007
